# %%
odbc_url = """Driver={Amazon Redshift (x64)}; 
Server=default-workgroup.537124937477.us-east-2.redshift-serverless.amazonaws.com; 
Database=dev;
UID=vincent;
PWD=Microsoft2024;"""


import pyodbc
import pandas as pd
import numpy as np

conn = pyodbc.connect(odbc_url)
print(conn)
if conn:
        # Use the connection to execute queries
    cursor = conn.cursor()
    cursor.execute("""SELECT
                    *
            FROM
    "dev"."public"."sales";""")
    for row in cursor.fetchall():
        print(row)

    conn.close()
# Out:
# <pyodbc.Connection object at 0x7f769f613430>
# (1, 1, 101, datetime.date(2023, 11, 19), 10, Decimal('71.23'))
# (2, 2, 102, datetime.date(2023, 11, 20), 6, Decimal('89.72'))
# (3, 3, 103, datetime.date(2023, 11, 21), 5, Decimal('61.73'))
# (4, 100, 200, datetime.date(2023, 12, 31), 9, Decimal('20.33'))

# %%
import pandas as pd

conn = pyodbc.connect(odbc_url)

df = pd.read_sql_query("""SELECT
                    *
            FROM
    "dev"."public"."sales";""", conn)
df.head()
# Out:
# /tmp/ipykernel_172481/2995974418.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""SELECT
#    saleid  productid  customerid    saledate  quantity  unitprice
# 0       1          1         101  2023-11-19        10      71.23
# 1       2          2         102  2023-11-20         6      89.72
# 2       3          3         103  2023-11-21         5      61.73
# 3       4        100         200  2023-12-31         9      20.33
