# %%
import os 
import pandas as pd
import json

queries_file = '../queries.json'
if os.path.exists(queries_file):
    with open(queries_file, 'r') as file:
        queries = json.load(file)
    df = pd.DataFrame(queries)

# %%
# Replace newline characters in the DataFrame
df_cleaned = df.replace('\n', ' ', regex=True)

# Convert the cleaned DataFrame to markdown
df_cleaned.to_markdown(index=False)
# Out:
# '| question                               | sql_query                                                                                                                                                                                                                                                                                 |\n|:---------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| what are the top 3 product categories? | SELECT TOP 3 pc.Name AS ProductCategory, SUM(sod.LineTotal) AS TotalSales FROM SalesLT.Product p JOIN SalesLT.ProductCategory pc ON p.ProductCategoryID = pc.ProductCategoryID JOIN SalesLT.SalesOrderDetail sod ON p.ProductID = sod.ProductID GROUP BY pc.Name ORDER BY TotalSales DESC |'
